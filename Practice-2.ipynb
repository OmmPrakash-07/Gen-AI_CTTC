# %% [markdown]
# <a href="https://colab.research.google.com/github/Priya-git2005/Gen-AI_CTTC/blob/main/Practice-2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
bean = pd.read_excel("/content/Dry_Bean_Dataset.xlsx")

# %%
bean

# %%
# Null value check
bean.isnull().sum()

# %%
bean.dtypes

# %%
bean.Class.unique()
# Out:
# array(['SEKER', 'BARBUNYA', 'BOMBAY', 'CALI', 'HOROZ', 'SIRA', 'DERMASON'],
#       dtype=object)

# %%
bean.info()

# %%
bean.describe()

# %%
bean.shape

# %%
sns.pairplot(bean, hue="Class")
plt.show()

# %%
sns.pairplot(
    bean.sample(500, random_state=42),
    hue="Class"
)
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

# Create Label Encoder
le = LabelEncoder()

# Encode the Class column
bean["Class"] = le.fit_transform(bean["Class"])

# Display first 5 rows
bean.head()

# %%
bean["Class"].unique()

# %%
class_mapping = dict(zip(le.classes_, le.transform(le.classes_)))
print(class_mapping)

# %%
bean.head()

# %%
# Input Features
x = bean.drop("Class", axis=1)

# Output / Target
y = bean["Class"]

# %%
x

# %%
x.head()

# %%
y

# %%
y.head()

# %%
print("Input Shape :", x.shape)
print("Output Shape :", y.shape)

# %%
from tensorflow.keras.utils import to_categorical

# %%
y = to_categorical(y)

# %%
print(y)

# %%
print(y.shape)

# %%
# train test split

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(
    x,
    y,
    test_size=0.2,
    random_state=42
)

# %%
print("x_train shape :", x_train.shape)
print("x_test shape  :", x_test.shape)
print("y_train shape :", y_train.shape)
print("y_test shape  :", y_test.shape)

# %%
#scaler methods

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# %%
x_train = scaler.fit_transform(x_train)

# %%
x_test = scaler.transform(x_test)

# %%
print(x_train)

# %%
#model create
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()

#Input Layer
model.add(Dense(16, input_dim=16, activation='relu'))

#Hidden Layer
model.add(Dense(32, activation='relu'))
model.add(Dense(16, activation='relu'))

#Output Layer
model.add(Dense(7, activation='softmax'))

#Compile

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_8 (Dense)                 │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 32)             │           544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 7)              │           119 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,463 (5.71 KB)
#  Trainable params: 1,463 (5.71 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train Model

history = model.fit(
    x_train,
    y_train,
    epochs=50,
    batch_size=32,
    validation_data=(x_test, y_test)
)

# %%
#pred

pred = model.predict(x_test)

# %%
pred = np.argmax(pred, axis=1)
y_true = np.argmax(y_test, axis=1)

# %%
print(pred)

# %%
result = pd.DataFrame({
    "Actual": y_true,
    "Predicted": pred
})

result.head(10)

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_true, pred)
print("Accuracy :", accuracy)

# %%
from sklearn.metrics import classification_report

print(classification_report(y_true, pred))

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_true, pred)

sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %%
y_test

# %%
y_test_labels = np.argmax(y_test, axis=1)
print(y_test_labels)

# %%
print("Actual    :", y_test_labels[:10])
print("Predicted :", pred[:10])

# %%
pred = model.predict(x_test)
pred

# %%
import numpy as np

b = np.argmax(pred, axis=1)
b

# %%
c = np.argmax(y_test, axis=1)
c

# %%
from sklearn.metrics import accuracy_score, mean_squared_error

ac = accuracy_score(b, c)
mse = mean_squared_error(b, c)

print("Accuracy :", ac)
print("Mean Squared Error :", mse)

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
bean["Class"] = le.fit_transform(bean["Class"])

# %%
pred = model.predict(x_test)

predicted_classes = np.argmax(pred, axis=1)

predicted_beans = le.inverse_transform(predicted_classes)

print(predicted_beans)

# %%
actual_classes = np.argmax(y_test, axis=1)

actual_beans = le.inverse_transform(actual_classes)

print(actual_beans)

# %%
result = pd.DataFrame({
    "Actual": actual_beans,
    "Predicted": predicted_beans
})

result.head(20)

# %%
# Convert actual labels back to bean names
actual_classes = np.argmax(y_test, axis=1)
actual_beans = le.inverse_transform(actual_classes)

# Convert predicted labels back to bean names
predicted_classes = np.argmax(pred, axis=1)
predicted_beans = le.inverse_transform(predicted_classes)

# Display Actual vs Predicted
for actual, predicted in zip(actual_beans, predicted_beans):
    print("Actual:", actual, "| Predicted:", predicted)
